# %%
import pandas as pd
from datetime import datetime
import re

# %%
house = pd.read_csv("./loren_data/house_2022-07-15.csv")
house.head()
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0             2021      10/04/2021       2021-09-27  joint     BP
# 1             2021      10/04/2021       2021-09-13  joint    XOM
# 2             2021      10/04/2021       2021-09-10  joint   ILPT
# 3             2021      10/04/2021       2021-09-28  joint     PM
# 4             2021      10/04/2021       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount          representative district  \
# 0   $1,001 - $15,000      Hon. Virginia Foxx     NC05
# 1   $1,001 - $15,000      Hon. Virginia Foxx     NC05
# 2  $15,001 - $50,000      Hon. Virginia Foxx     NC05
# 3  $15,001 - $50,000      Hon. Virginia Foxx     NC05
# 4   $1,001 - $15,000  Hon. Alan S. Lowenthal     CA47
#
#                                             ptr_link  cap_gains_over_200_usd
# 0  https://disclosures-clerk.house.gov/public_dis...                   False
# 1  https://disclosures-clerk.house.gov/public_dis...                   False
# 2  https://disclosures-clerk.house.gov/public_dis...                   False
# 3  https://disclosures-clerk.house.gov/public_dis...                   False
# 4  https://disclosures-clerk.house.gov/public_dis...                   False

# %%
house.dtypes
# Out:
# disclosure_year            int64
# disclosure_date           object
# transaction_date          object
# owner                     object
# ticker                    object
# asset_description         object
# type                      object
# amount                    object
# representative            object
# district                  object
# ptr_link                  object
# cap_gains_over_200_usd      bool
# dtype: object

# %%
house.isnull().sum()
# Out:
# disclosure_year              0
# disclosure_date              0
# transaction_date             0
# owner                     5614
# ticker                       0
# asset_description            4
# type                         0
# amount                       0
# representative               0
# district                     0
# ptr_link                     0
# cap_gains_over_200_usd       0
# dtype: int64

# %%
house[house['owner'].isnull()].head()
# Out:
#     disclosure_year disclosure_date transaction_date owner ticker  \
# 6              2021      12/01/2021       2021-11-30   NaN  KPLTW
# 7              2021      12/01/2021       2021-11-18   NaN    AMD
# 8              2021      12/01/2021       2021-11-18   NaN   AAPL
# 9              2021      12/01/2021       2021-11-24   NaN   MSFT
# 10             2021      12/01/2021       2021-11-24   NaN     MS
#
#                   asset_description       type               amount  \
# 6   Katapult Holdings Inc - Warrant   purchase     $1,001 - $15,000
# 7        Advanced Micro Devices Inc  sale_full   $50,001 - $100,000
# 8                         Apple Inc  sale_full   $50,001 - $100,000
# 9             Microsoft Corporation   purchase   $50,001 - $100,000
# 10                   Morgan Stanley   purchase  $100,001 - $250,000
#
#         representative district  \
# 6    Hon. Austin Scott     GA08
# 7   Hon. Thomas Suozzi     NY03
# 8   Hon. Thomas Suozzi     NY03
# 9   Hon. Thomas Suozzi     NY03
# 10  Hon. Thomas Suozzi     NY03
#
#                                              ptr_link  cap_gains_over_200_usd
# 6   https://disclosures-clerk.house.gov/public_dis...                   False
# 7   https://disclosures-clerk.house.gov/public_dis...                   False
# 8   https://disclosures-clerk.house.gov/public_dis...                   False
# 9   https://disclosures-clerk.house.gov/public_dis...                   False
# 10  https://disclosures-clerk.house.gov/public_dis...                   False

# %%
percent_null = house.owner.isnull().sum()/len(house)
percent_null
# Out:
# 0.3779198922921575

# %%
house['owner'].value_counts(dropna = False)
# Out:
# NaN          5614
# joint        4635
# self         2897
# --           1315
# dependent     394
# Name: owner, dtype: int64

# %% [markdown]
# We decided to drop the `'owner'` column because there were so many nulls and '--'. For our purposes, to see if congresspeople are taking advantage of insider trading, the distinction of who in the congressperson's family technically owns the equity is unimportant. It would be interesting to explore ownership, but there's just too many nulls.

# %%
house.drop(columns = ['owner'], inplace = True)

# %%
house['disclosure_date'] = pd.to_datetime(house['disclosure_date'], yearfirst=True)

# %% [markdown]
# We discovered some wonky years in the transaction dates. Fortunately, it was highly likely the disclosure year was the year of the transaction, so we substituted that for the year

# %% [markdown]
# This [stackoverflow answer](https://stackoverflow.com/a/56968849) helped to understand how to pull the first item from within the list.

# %%
house['transaction_date'] = house['transaction_date'].str.split('-')

weird_years = house[(house['transaction_date'].str[0] != '2017') &
      (house['transaction_date'].str[0] != '2018') &
      (house['transaction_date'].str[0] != '2019') &
      (house['transaction_date'].str[0] != '2020') &
      (house['transaction_date'].str[0] != '2021') &
      (house['transaction_date'].str[0] != '2022')]

for i in weird_years.index:
    house.loc[i, 'transaction_date'][0] = str(house.loc[i, 'disclosure_year'])

# %%
#verifying the years have been fixed
house[(house['transaction_date'].str[0] != '2017') &
      (house['transaction_date'].str[0] != '2018') &
      (house['transaction_date'].str[0] != '2019') &
      (house['transaction_date'].str[0] != '2020') &
      (house['transaction_date'].str[0] != '2021') &
      (house['transaction_date'].str[0] != '2022')]
# Out:
# Empty DataFrame
# Columns: [disclosure_year, disclosure_date, transaction_date, ticker, asset_description, type, amount, representative, district, ptr_link, cap_gains_over_200_usd]
# Index: []

# %%
house['transaction_date'] = house['transaction_date'].str.join('-')
house['transaction_date'] = pd.to_datetime(house['transaction_date'])
house.dtypes
# Out:
# disclosure_year                    int64
# disclosure_date           datetime64[ns]
# transaction_date          datetime64[ns]
# ticker                            object
# asset_description                 object
# type                              object
# amount                            object
# representative                    object
# district                          object
# ptr_link                          object
# cap_gains_over_200_usd              bool
# dtype: object

# %%
#verifying the range of dates is what we expect
house['transaction_date'].describe(datetime_is_numeric=True)
# Out:
# count                            14855
# mean     2020-11-29 17:24:47.256815616
# min                2017-09-05 00:00:00
# 25%                2020-04-22 00:00:00
# 50%                2020-11-19 00:00:00
# 75%                2021-06-08 00:00:00
# max                2022-12-31 00:00:00
# Name: transaction_date, dtype: object

# %%
house['amount'].value_counts()
# Out:
# $1,001 - $15,000            10447
# $15,001 - $50,000            2362
# $50,001 - $100,000            750
# $100,001 - $250,000           572
# $250,001 - $500,000           243
# $1,001 -                      242
# $500,001 - $1,000,000         150
# $1,000,001 - $5,000,000        41
# $1,000,000 +                   30
# $5,000,001 - $25,000,000        9
# $1,000 - $15,000                4
# $15,000 - $50,000               3
# $50,000,000 +                   1
# $1,000,000 - $5,000,000         1
# Name: amount, dtype: int64

# %% [markdown]
# Review of .replace() from [here](https://www.symbiosisacademy.org/tutorial-index/pandas-search-replace-values-columns/)

# %%
house = house.replace(to_replace={'amount':['$1,001 -', '$1,000 - $15,000']}, value= '$1,001 - $15,000')
house = house.replace(to_replace={'amount':['$1,000,000 +', '$1,000,000 - $5,000,000']}, value= '$1,000,001 - $5,000,000')
house = house.replace(to_replace={'amount':['$15,000 - $50,000']}, value= '$15,001 - $50,000')
house['amount'].value_counts()
# Out:
# $1,001 - $15,000            10693
# $15,001 - $50,000            2365
# $50,001 - $100,000            750
# $100,001 - $250,000           572
# $250,001 - $500,000           243
# $500,001 - $1,000,000         150
# $1,000,001 - $5,000,000        72
# $5,000,001 - $25,000,000        9
# $50,000,000 +                   1
# Name: amount, dtype: int64

# %%
house['amount'] = house['amount'].str.split(' ') 

for i in range(0, len(house)):
    if len(house.loc[i, 'amount']) == 3:
        house.loc[i, 'amount'] = house.loc[i, 'amount'][2]
    else:
        house.loc[i, 'amount'] = house.loc[i, 'amount'][0]
        
house['amount'] = house['amount'].map(lambda x: x.replace('$', '').replace(',', ''))
house['amount'] = house['amount'].astype(int)
house['amount'].value_counts()
# Out:
# 15000       10693
# 50000        2365
# 100000        750
# 250000        572
# 500000        243
# 1000000       150
# 5000000        72
# 25000000        9
# 50000000        1
# Name: amount, dtype: int64

# %%
house.dtypes
# Out:
# disclosure_year                    int64
# disclosure_date           datetime64[ns]
# transaction_date          datetime64[ns]
# ticker                            object
# asset_description                 object
# type                              object
# amount                             int64
# representative                    object
# district                          object
# ptr_link                          object
# cap_gains_over_200_usd              bool
# dtype: object

# %%
house['ticker'].value_counts()
# Out:
# --       1208
# MSFT      244
# AAPL      181
# NTAP      130
# TDDXX     122
#          ...
# MSTR        1
# MC          1
# MPWR        1
# HEI         1
# FLCB        1
# Name: ticker, Length: 2123, dtype: int64

# %%
house['ticker'].value_counts().values[0]/len(house)
# Out:
# 0.08131942107034669

# %%
house[house['ticker'] == '--'].head()
# Out:
#     disclosure_year disclosure_date transaction_date ticker  \
# 56             2020      2020-09-22       2020-08-17     --
# 57             2021      2021-03-23       2021-01-27     --
# 58             2021      2021-03-23       2021-02-08     --
# 59             2021      2021-03-23       2021-02-08     --
# 61             2021      2021-03-23       2021-02-19     --
#
#           asset_description          type  amount          representative  \
# 56  Metallic Minerals Corp.  sale_partial  250000    Mr. TJ John (Tj) Cox
# 57   Zimmer Biomet Holdings  sale_partial   15000  Hon. Alan S. Lowenthal
# 58   Zimmer Biomet Holdings     sale_full   15000  Hon. Alan S. Lowenthal
# 59   Zimmer Biomet Holdings      purchase   15000  Hon. Alan S. Lowenthal
# 61            Celegene Corp     sale_full   50000  Hon. Alan S. Lowenthal
#
#    district                                           ptr_link  \
# 56     CA21  https://disclosures-clerk.house.gov/public_dis...
# 57     CA47  https://disclosures-clerk.house.gov/public_dis...
# 58     CA47  https://disclosures-clerk.house.gov/public_dis...
# 59     CA47  https://disclosures-clerk.house.gov/public_dis...
# 61     CA47  https://disclosures-clerk.house.gov/public_dis...
#
#     cap_gains_over_200_usd
# 56                    True
# 57                   False
# 58                   False
# 59                   False
# 61                   False

# %%
tickers = pd.read_excel('./loren_data/US-Stock-Symbols.xlsx')
tickers = tickers[['Symbol', 'Name']]
tickers.columns = tickers.columns.map(lambda x: x.lower())

tickers.head()
# Out:
#   symbol                                         name
# 0   AAPL                                   Apple Inc.
# 1    XOM                      Exxon Mobil Corporation
# 2   MSFT                        Microsoft Corporation
# 3  BAC^I                  Bank of America Corporation
# 4    IBM  International Business Machines Corporation

# %%
for i in house.loc[house['ticker'] == '--']['asset_description']:
    symbol = tickers.loc[tickers['name'] == i, 'symbol']
    house.loc[house['asset_description'] == i, 'ticker'] = symbol

# %%
house.ticker.value_counts()
# Out:
# MSFT     244
# AAPL     181
# NTAP     130
# TDDXX    122
# FB       115
#         ...
# MGPI       1
# MSTR       1
# MC         1
# MPWR       1
# FLCB       1
# Name: ticker, Length: 2117, dtype: int64

# %%
house[house['ticker'] == '--']
# Out:
# Empty DataFrame
# Columns: [disclosure_year, disclosure_date, transaction_date, ticker, asset_description, type, amount, representative, district, ptr_link, cap_gains_over_200_usd]
# Index: []

# %%
house.describe()
# Out:
#        disclosure_year        amount
# count     14855.000000  1.485500e+04
# mean       2020.634938  9.445608e+04
# std           0.703684  8.227438e+05
# min        2020.000000  1.500000e+04
# 25%        2020.000000  1.500000e+04
# 50%        2021.000000  1.500000e+04
# 75%        2021.000000  5.000000e+04
# max        2022.000000  5.000000e+07

# %% [markdown]
# We need our columns to agree with the Senate dataframe columns, so we made the following changes. While we erred on the side of keeping information for now, we dropped the 'ptr_link' because we don't anticipate doing any analysis on it. If we need it, we'll come back and reference it from the csv or from prior to this point.
#
# This [stackoverflow answer](https://stackoverflow.com/a/54195568) helped us to find the differences between the lists of columns

# %%
house_cols = list(house.columns)

senate_cols = ['transaction_date', 'owner', 'ticker', 'asset_description',
       'asset_type', 'type', 'amount', 'comment', 'senator', 'ptr_link',
       'disclosure_date', 'year'] 

house_different_cols = list(set(house_cols).difference(senate_cols))
print(f'In House, not in Senate: {house_different_cols}')

senate_different_cols = list(set(senate_cols).difference(house_cols))
print(f'In Senate, not in House: {senate_different_cols}')
# Out:
# In House, not in Senate: ['representative', 'district', 'disclosure_year', 'cap_gains_over_200_usd']
# In Senate, not in House: ['senator', 'owner', 'asset_type', 'year', 'comment']

# %%
house['chamber'] = 'house'
house.drop(columns = ['ptr_link', 'cap_gains_over_200_usd', 'disclosure_year'], inplace = True)
house.rename(columns = {'representative': 'name', 'district': 'represents'}, inplace = True)

# %%
house_cols = list(house.columns)

senate_cols = ['transaction_date', 'owner', 'ticker', 'asset_description',
       'asset_type', 'type', 'amount', 'comment', 'senator', 'ptr_link',
       'disclosure_date', 'year'] 

house_different_cols = list(set(house_cols).difference(senate_cols))
print(f'In House, not in Senate: {house_different_cols}')

senate_different_cols = list(set(senate_cols).difference(house_cols))
print(f'In Senate, not in House: {senate_different_cols}')
# Out:
# In House, not in Senate: ['name', 'chamber', 'represents']
# In Senate, not in House: ['senator', 'owner', 'ptr_link', 'asset_type', 'year', 'comment']

# %% [markdown]
# The following came from [this github](https://github.com/unitedstates/congress-legislators/).

# %%
#NOT IN .py FILE AS OF R2022-07-19 15:00

current_legislators = pd.read_csv('./loren_data/legislators-current.csv')
current_legislators.shape
# Out:
# (537, 34)

# %%
current_legislators.head()
# Out:
#   last_name first_name middle_name suffix nickname             full_name  \
# 0     Brown    Sherrod         NaN    NaN      NaN         Sherrod Brown
# 1  Cantwell      Maria         NaN    NaN      NaN        Maria Cantwell
# 2    Cardin   Benjamin          L.    NaN      NaN    Benjamin L. Cardin
# 3    Carper     Thomas     Richard    NaN      NaN      Thomas R. Carper
# 4     Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
#
#      birthday gender type state  ...  opensecrets_id  lis_id  \
# 0  1952-11-09      M  sen    OH  ...       N00003535    S307
# 1  1958-10-13      F  sen    WA  ...       N00007836    S275
# 2  1943-10-05      M  sen    MD  ...       N00001955    S308
# 3  1947-01-23      M  sen    DE  ...       N00012508    S277
# 4  1960-04-13      M  sen    PA  ...       N00027503    S309
#
#                fec_ids cspan_id govtrack_id votesmart_id  ballotpedia_id  \
# 0  H2OH13033,S6OH00163   5051.0      400050      27018.0   Sherrod Brown
# 1  S8WA00194,H2WA01054  26137.0      300018      27122.0  Maria Cantwell
# 2  H6MD03177,S6MD03177   4004.0      400064      26888.0      Ben Cardin
# 3            S8DE00079    663.0      300019      22421.0      Tom Carper
# 4            S6PA00217  47036.0      412246       2541.0  Bob Casey, Jr.
#
#   washington_post_id icpsr_id    wikipedia_id
# 0                NaN  29389.0   Sherrod Brown
# 1                NaN  39310.0  Maria Cantwell
# 2                NaN  15408.0      Ben Cardin
# 3                NaN  15015.0      Tom Carper
# 4                NaN  40703.0   Bob Casey Jr.
#
# [5 rows x 34 columns]

# %%
current_leg_cols = list(current_legislators.columns)
current_leg_cols
# Out:
# ['last_name',
#  'first_name',
#  'middle_name',
#  'suffix',
#  'nickname',
#  'full_name',
#  'birthday',
#  'gender',
#  'type',
#  'state',
#  'district',
#  'senate_class',
#  'party',
#  'url',
#  'address',
#  'phone',
#  'contact_form',
#  'rss_url',
#  'twitter',
#  'facebook',
#  'youtube',
#  'youtube_id',
#  'bioguide_id',
#  'thomas_id',
#  'opensecrets_id',
#  'lis_id',
#  'fec_ids',
#  'cspan_id',
#  'govtrack_id',
#  'votesmart_id',
#  'ballotpedia_id',
#  'washington_post_id',
#  'icpsr_id',
#  'wikipedia_id']

# %%
historical_legislators = pd.read_csv('./loren_data/legislators-historical.csv')
historical_legislators.shape
# Out:
# (12056, 34)

# %%
historical_leg_cols = list(historical_legislators.columns)
historical_leg_cols
# Out:
# ['last_name',
#  'first_name',
#  'middle_name',
#  'suffix',
#  'nickname',
#  'full_name',
#  'birthday',
#  'gender',
#  'type',
#  'state',
#  'district',
#  'senate_class',
#  'party',
#  'url',
#  'address',
#  'phone',
#  'contact_form',
#  'rss_url',
#  'twitter',
#  'facebook',
#  'youtube',
#  'youtube_id',
#  'bioguide_id',
#  'thomas_id',
#  'opensecrets_id',
#  'lis_id',
#  'fec_ids',
#  'cspan_id',
#  'govtrack_id',
#  'votesmart_id',
#  'ballotpedia_id',
#  'washington_post_id',
#  'icpsr_id',
#  'wikipedia_id']

# %%
current_diff_cols = list(set(current_leg_cols).difference(historical_leg_cols))
current_diff_cols
# Out:
# []

# %% [markdown]
# The above determines the columns are the same. We shrank the historical ones to eliminate irrelevant entries. Making birthdays datetime. Referenced [this site](https://www.w3schools.com/python/python_datetime.asp).

# %%
historical_legislators['birthday'] = pd.to_datetime(historical_legislators['birthday'], format = '%Y-%m-%d')

# %%
current_legislators['birthday'] = pd.to_datetime(current_legislators['birthday'], format = '%Y-%m-%d')

# %%
historical_legislators = historical_legislators[historical_legislators['birthday'] > datetime(1922,1, 1)]

# %%
relevant_legislators = pd.concat([current_legislators, historical_legislators])

# %%
relevant_legislators = relevant_legislators[['last_name', 'first_name', 'middle_name', 'suffix',
                                             'full_name', 'birthday', 'gender', 'type', 'state', 'party', 'district']]

# %%
relevant_legislators.dtypes
# Out:
# last_name              object
# first_name             object
# middle_name            object
# suffix                 object
# full_name              object
# birthday       datetime64[ns]
# gender                 object
# type                   object
# state                  object
# party                  object
# district              float64
# dtype: object

# %%
relevant_legislators.head()
# Out:
#   last_name first_name middle_name suffix             full_name   birthday  \
# 0     Brown    Sherrod         NaN    NaN         Sherrod Brown 1952-11-09
# 1  Cantwell      Maria         NaN    NaN        Maria Cantwell 1958-10-13
# 2    Cardin   Benjamin          L.    NaN    Benjamin L. Cardin 1943-10-05
# 3    Carper     Thomas     Richard    NaN      Thomas R. Carper 1947-01-23
# 4     Casey     Robert          P.    Jr.  Robert P. Casey, Jr. 1960-04-13
#
#   gender type state     party  district
# 0      M  sen    OH  Democrat       NaN
# 1      F  sen    WA  Democrat       NaN
# 2      M  sen    MD  Democrat       NaN
# 3      M  sen    DE  Democrat       NaN
# 4      M  sen    PA  Democrat       NaN

# %%
house.head()
# Out:
#   disclosure_date transaction_date ticker  \
# 0      2021-10-04       2021-09-27     BP
# 1      2021-10-04       2021-09-13    XOM
# 2      2021-10-04       2021-09-10   ILPT
# 3      2021-10-04       2021-09-28     PM
# 4      2021-10-04       2021-09-17    BLK
#
#                                    asset_description          type  amount  \
# 0                                             BP plc      purchase   15000
# 1                            Exxon Mobil Corporation      purchase   15000
# 2  Industrial Logistics Properties Trust - Common...      purchase   50000
# 3                   Phillip Morris International Inc      purchase   50000
# 4                                      BlackRock Inc  sale_partial   15000
#
#                      name represents chamber
# 0      Hon. Virginia Foxx       NC05   house
# 1      Hon. Virginia Foxx       NC05   house
# 2      Hon. Virginia Foxx       NC05   house
# 3      Hon. Virginia Foxx       NC05   house
# 4  Hon. Alan S. Lowenthal       CA47   house

# %%
relevant_legislators.tail()
# Out:
#          last_name first_name middle_name suffix         full_name   birthday  \
# 12051        Young        Don          E.    NaN         Don Young 1933-06-09
# 12052  Fortenberry       Jeff        Lane    NaN  Jeff Fortenberry 1960-12-27
# 12053         Vela    Filemon         NaN    NaN      Filemon Vela 1963-02-13
# 12054         Reed        Tom          W.    NaN          Tom Reed 1971-11-18
# 12055      Delgado    Antonio         NaN    NaN   Antonio Delgado 1977-01-19
#
#       gender type state       party  district
# 12051      M  rep    AK  Republican       0.0
# 12052      M  rep    NE  Republican       1.0
# 12053      M  rep    TX    Democrat      34.0
# 12054      M  rep    NY  Republican      23.0
# 12055      M  rep    NY    Democrat      19.0

# %%
house['name'] = house['name'].map(lambda x: x.replace("Hon. ", ""))

# %%
house['first_name'] = house['name'].map(lambda x: x.split()[0])

# %%
house['last_name'] = house['name'].map(lambda x: x.split()[-1])

# %% [markdown]
# [This](https://stackoverflow.com/a/20772805) is one of several places I read about a bug in .loc()

# %% [markdown]
# for i in house.index[:5]:
#     first_name = house.loc[i, 'first_name']
#     last_name = house.loc[i, 'last_name']
#     first_df = relevant_legislators.loc[relevant_legislators['first_name'] == first_name]
#     rep_df = first_df.loc[first_df['last_name'] == last_name]
#     party = rep_df['party'].values
#     #test_df = pd.DataFrame()
#     #test_df['party'] = party
#     print(type(party))

# %% [markdown]
# for i in range(0, len(house)):
#     first_name = house.loc[i, 'first_name']
#     last_name = house.loc[i, 'last_name']
#     first_df = relevant_legislators[relevant_legislators['first_name'] == first_name]
#     rep_df = first_df[first_df['last_name'] == last_name]
#     party = rep_df['party']
#     house.loc[i]['party'] = party
#     #test_df = pd.DataFrame()
#     #test_df['party'] = party
#    # print(house.head())

# %%
relevant_legislators[relevant_legislators['last_name'] == 'McEachin']
# Out:
#     last_name first_name middle_name suffix           full_name   birthday  \
# 360  McEachin         A.      Donald    NaN  A. Donald McEachin 1961-10-10
#
#     gender type state     party  district
# 360      M  rep    VA  Democrat       4.0

# %%
house.iloc[5]
# Out:
# disclosure_date           2021-12-01 00:00:00
# transaction_date          2021-12-01 00:00:00
# ticker                                    AXP
# asset_description    American Express Company
# type                                 purchase
# amount                                  15000
# name                    Aston Donald McEachin
# represents                               VA04
# chamber                                 house
# first_name                              Aston
# last_name                            McEachin
# Name: 5, dtype: object

# %%
house.shape
# Out:
# (14855, 11)

# %%
house[house['name'] == "Tom O'Halleran"]
# Out:
#      disclosure_date transaction_date ticker    asset_description       type  \
# 6773      2020-04-17       2020-03-31    CAT    Caterpillar, Inc.  sale_full
# 6774      2020-04-17       2020-03-31    NEM  Newmont Corporation  sale_full
#
#       amount            name represents chamber first_name   last_name party  \
# 6773   15000  Tom O'Halleran       AZ01   house        Tom  O'Halleran
# 6774   15000  Tom O'Halleran       AZ01   house        Tom  O'Halleran
#
#      birthday gender
# 6773
# 6774

# %%
house.loc[house['last_name'] == 'FACS', 'last_name'] = 'Dunn'
house.loc[house['last_name'] == 'Arenholz', 'last_name'] = 'Hinson'

# %%
relevant_legislators.loc[relevant_legislators['last_name'].str.contains('Halleran'), 'last_name'] = "O'Halleran"
relevant_legislators.loc[relevant_legislators['last_name'] == 'Sánchez', 'last_name'] = 'Sanchez'

# %%
house['party'] = ''
house['birthday'] = ''
house['gender'] = ''

name = set()
for i in house.index:
    #try:
    first_name = house.loc[i, 'first_name']
    last_name = house.loc[i, 'last_name']
    party = relevant_legislators[(relevant_legislators['first_name'] == first_name) & (relevant_legislators['last_name'].map(lambda x: x.split()[-1]) == last_name)]['party'].values
    birthday = relevant_legislators[(relevant_legislators['first_name'] == first_name) & (relevant_legislators['last_name'].map(lambda x: x.split()[-1]) == last_name)]['birthday'].values
    gender = relevant_legislators[(relevant_legislators['first_name'] == first_name) & (relevant_legislators['last_name'].map(lambda x: x.split()[-1]) == last_name)]['gender'].values
    if len(party) == 0:
        party = relevant_legislators[(relevant_legislators['district'] == float(house.loc[i, 'represents'][-2:])) & (relevant_legislators['last_name'].map(lambda x: x.split()[-1]) == last_name)]['party'].values
        birthday = relevant_legislators[(relevant_legislators['district'] == float(house.loc[i, 'represents'][-2:])) & (relevant_legislators['last_name'].map(lambda x: x.split()[-1]) == last_name)]['birthday'].values
        gender = relevant_legislators[(relevant_legislators['district'] == float(house.loc[i, 'represents'][-2:])) & (relevant_legislators['last_name'].map(lambda x: x.split()[-1]) == last_name)]['gender'].values
    if len(party) == 0:
        name.add(str(first_name) + ' ' + str(last_name))
    house['party'][i] = party[0]
    house['birthday'][i] = birthday[0]
    house['gender'][i] = gender[0]
    #except:
        #print(i)
        #break
print(len(name))
# Out:
# /var/folders/5_/498w081d1837cc82dmb4hwmc0000gn/T/ipykernel_42246/3629497685.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['party'][i] = party[0]
# /var/folders/5_/498w081d1837cc82dmb4hwmc0000gn/T/ipykernel_42246/3629497685.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['birthday'][i] = birthday[0]
# /var/folders/5_/498w081d1837cc82dmb4hwmc0000gn/T/ipykernel_42246/3629497685.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['gender'][i] = gender[0]
# 0

# %%
name
# Out:
# {"Tom O'Halleran"}

# %%
relevant_legislators[relevant_legislators['last_name'] == 'Sanchez']
# Out:
#       last_name first_name middle_name suffix        full_name   birthday  \
# 11842   Sanchez    Loretta          B.    NaN  Loretta Sanchez 1960-01-07
#
#       gender type state     party  district
# 11842      F  rep    CA  Democrat      46.0

# %%
#linda sanchez had an accento
relevant_legislators[relevant_legislators['first_name'] == 'Linda']
# Out:
#       last_name first_name middle_name suffix         full_name   birthday  \
# 189     Sánchez      Linda          T.    NaN  Linda T. Sánchez 1969-01-28
# 11208     Smith      Linda         NaN    NaN               NaN 1950-07-16
#
#       gender type state       party  district
# 189        F  rep    CA    Democrat      38.0
# 11208      F  rep    WA  Republican       3.0

# %%
house[house['last_name'] == 'Sanchez']
# Out:
#      disclosure_date transaction_date ticker            asset_description  \
# 9730      2020-09-13       2019-02-22    BAC  Bank of America Corporation
# 9731      2020-09-13       2019-02-22    ENB                Enbridge Inc.
# 9732      2020-09-13       2019-02-22      F               Ford Motor Co.
# 9733      2020-09-13       2019-02-22   RTNB    Root 9 B Technologies Inc
# 9734      2020-09-13       2019-02-22    UBS                 UBS Group AG
#
#            type  amount              name represents chamber first_name  \
# 9730  sale_full   15000  Linda T. Sanchez       CA38   house      Linda
# 9731  sale_full   15000  Linda T. Sanchez       CA38   house      Linda
# 9732  sale_full   15000  Linda T. Sanchez       CA38   house      Linda
# 9733  sale_full   15000  Linda T. Sanchez       CA38   house      Linda
# 9734  sale_full   15000  Linda T. Sanchez       CA38   house      Linda
#
#      last_name party birthday gender
# 9730   Sanchez
# 9731   Sanchez
# 9732   Sanchez
# 9733   Sanchez
# 9734   Sanchez

# %%
#finding O'Halleran character
str(relevant_legislators[relevant_legislators['last_name'].str.contains("Halleran")]['last_name'].str[1]).encode()
# Out:
# b"321    '\nName: last_name, dtype: object"

# %%
house[house['party'] == '']
# Out:
#       disclosure_date transaction_date ticker  \
# 6773       2020-04-17       2020-03-31    CAT
# 6774       2020-04-17       2020-03-31    NEM
# 6775       2020-07-14       2020-06-12    JNJ
# 6776       2020-07-14       2020-06-10    MCD
# 6777       2020-07-14       2020-06-01      T
# ...               ...              ...    ...
# 14850      2020-06-10       2020-04-09    SWK
# 14851      2020-06-10       2020-04-09    USB
# 14852      2020-06-10       2020-03-13    BMY
# 14853      2020-06-10       2020-03-13    LLY
# 14854      2020-06-10       2020-03-13    DIS
#
#                        asset_description          type   amount  \
# 6773                   Caterpillar, Inc.     sale_full    15000
# 6774                 Newmont Corporation     sale_full    15000
# 6775   Johnson & Johnson GLB 02.450% MAR      purchase    15000
# 6776   McDonalds Corp Ser MTN 03.700% JA      purchase    15000
# 6777              AT&T INC CLD GLB 02.45     sale_full    15000
# ...                                  ...           ...      ...
# 14850       Stanley Black & Decker, Inc.  sale_partial    15000
# 14851                       U.S. Bancorp  sale_partial    15000
# 14852       Bristol-Myers Squibb Company     sale_full   250000
# 14853              Eli Lilly and Company     sale_full  1000000
# 14854                Walt Disney Company     sale_full   500000
#
#                       name represents chamber first_name   last_name party  \
# 6773        Tom O'Halleran       AZ01   house        Tom  O'Halleran
# 6774        Tom O'Halleran       AZ01   house        Tom  O'Halleran
# 6775          David P. Roe       TN01   house      David         Roe
# 6776          David P. Roe       TN01   house      David         Roe
# 6777          David P. Roe       TN01   house      David         Roe
# ...                    ...        ...     ...        ...         ...   ...
# 14850        Ed Perlmutter       CO07   house         Ed  Perlmutter
# 14851        Ed Perlmutter       CO07   house         Ed  Perlmutter
# 14852  Nicholas Van Taylor       TX03   house   Nicholas      Taylor
# 14853  Nicholas Van Taylor       TX03   house   Nicholas      Taylor
# 14854  Nicholas Van Taylor       TX03   house   Nicholas      Taylor
#
#       birthday gender
# 6773
# 6774
# 6775
# 6776
# 6777
# ...        ...    ...
# 14850
# 14851
# 14852
# 14853
# 14854
#
# [8082 rows x 14 columns]

# %%
house[house['last_name'].isnull()]
# Out:
#       disclosure_date transaction_date ticker  \
# 0          2021-10-04       2021-09-27     BP
# 1          2021-10-04       2021-09-13    XOM
# 2          2021-10-04       2021-09-10   ILPT
# 3          2021-10-04       2021-09-28     PM
# 4          2021-10-04       2021-09-17    BLK
# ...               ...              ...    ...
# 14850      2020-06-10       2020-04-09    SWK
# 14851      2020-06-10       2020-04-09    USB
# 14852      2020-06-10       2020-03-13    BMY
# 14853      2020-06-10       2020-03-13    LLY
# 14854      2020-06-10       2020-03-13    DIS
#
#                                        asset_description          type  \
# 0                                                 BP plc      purchase
# 1                                Exxon Mobil Corporation      purchase
# 2      Industrial Logistics Properties Trust - Common...      purchase
# 3                       Phillip Morris International Inc      purchase
# 4                                          BlackRock Inc  sale_partial
# ...                                                  ...           ...
# 14850                       Stanley Black & Decker, Inc.  sale_partial
# 14851                                       U.S. Bancorp  sale_partial
# 14852                       Bristol-Myers Squibb Company     sale_full
# 14853                              Eli Lilly and Company     sale_full
# 14854                                Walt Disney Company     sale_full
#
#         amount                 name represents chamber first_name last_name  \
# 0        15000        Virginia Foxx       NC05   house   Virginia       NaN
# 1        15000        Virginia Foxx       NC05   house   Virginia       NaN
# 2        50000        Virginia Foxx       NC05   house   Virginia       NaN
# 3        50000        Virginia Foxx       NC05   house   Virginia       NaN
# 4        15000    Alan S. Lowenthal       CA47   house       Alan       NaN
# ...        ...                  ...        ...     ...        ...       ...
# 14850    15000        Ed Perlmutter       CO07   house         Ed       NaN
# 14851    15000        Ed Perlmutter       CO07   house         Ed       NaN
# 14852   250000  Nicholas Van Taylor       TX03   house   Nicholas       NaN
# 14853  1000000  Nicholas Van Taylor       TX03   house   Nicholas       NaN
# 14854   500000  Nicholas Van Taylor       TX03   house   Nicholas       NaN
#
#       party birthday gender
# 0
# 1
# 2
# 3
# 4
# ...     ...      ...    ...
# 14850
# 14851
# 14852
# 14853
# 14854
#
# [14845 rows x 14 columns]

# %%
relevant_legislators[relevant_legislators['district'] == 23]
# Out:
#                last_name first_name middle_name suffix  \
# 130             McCarthy      Kevin         NaN    NaN
# 201    Wasserman Schultz     Debbie         NaN    NaN
# 516             Gonzales     Ernest     Anthony    NaN
# 10364               Rees     Thomas     Mankell    NaN
# 10388           Ammerman     Joseph    Scofield    NaN
# 10401             Caputo      Bruce    Faulkner    NaN
# 10628              Mottl     Ronald      Milton    NaN
# 10878         Bustamante     Albert       Garza    NaN
# 11394            Bonilla      Henry         NaN    NaN
# 11575             McHugh       John          M.    NaN
# 11593          Rodriguez       Ciro          D.    NaN
# 11664            Canseco  Francisco         NaN    NaN
# 11788            Gallego       Pete          P.    NaN
# 12018               Hurd       Will         NaN    NaN
# 12054               Reed        Tom          W.    NaN
#
#                        full_name   birthday gender type state       party  \
# 130               Kevin McCarthy 1965-01-26      M  rep    CA  Republican
# 201     Debbie Wasserman Schultz 1966-09-27      F  rep    FL    Democrat
# 516                Tony Gonzales 1980-10-10      M  rep    TX  Republican
# 10364                        NaN 1925-03-26      M  rep    CA    Democrat
# 10388                        NaN 1924-07-14      M  rep    PA    Democrat
# 10401                        NaN 1943-08-07      M  rep    NY  Republican
# 10628                        NaN 1934-02-06      M  rep    OH    Democrat
# 10878                        NaN 1935-04-08      M  rep    TX    Democrat
# 11394                        NaN 1954-01-02      M  rep    TX  Republican
# 11575                        NaN 1948-09-29      M  rep    NY  Republican
# 11593                        NaN 1946-12-09      M  rep    TX    Democrat
# 11664  Francisco "Quico" Canseco 1949-07-30      M  rep    TX  Republican
# 11788            Pete P. Gallego 1961-12-02      M  rep    TX    Democrat
# 12018                  Will Hurd 1977-08-19      M  rep    TX  Republican
# 12054                   Tom Reed 1971-11-18      M  rep    NY  Republican
#
#        district
# 130        23.0
# 201        23.0
# 516        23.0
# 10364      23.0
# 10388      23.0
# 10401      23.0
# 10628      23.0
# 10878      23.0
# 11394      23.0
# 11575      23.0
# 11593      23.0
# 11664      23.0
# 11788      23.0
# 12018      23.0
# 12054      23.0

# %% [markdown]
# take last names plus districts

# %%
name
# Out:
# {'Aston McEachin',
#  'Christopher Jacobs',
#  'Cindy Axne',
#  'Daniel Crenshaw',
#  'David Cawthorn',
#  'Debbie Schultz',
#  'Felix Moore',
#  'Greg Murphy',
#  'Greg Steube',
#  'James Banks',
#  'James Costa',
#  'James Hagedorn',
#  'James Hill',
#  'Kenneth Buck',
#  'Linda Sanchez',
#  'Michael Gallagher',
#  'Michael Garcia',
#  'Mr. Cox',
#  'Mr. Franklin',
#  'Mr. Meijer',
#  'Mrs. Greene',
#  'Neal FACS',
#  'Nicholas Taylor',
#  'None Arenholz',
#  'None Jacobs',
#  'None Manning',
#  'None Newman',
#  'None Ross',
#  'None Spartz',
#  'Richard Allen',
#  'Rohit Khanna',
#  'S. Krishnamoorthi',
#  'Scott Franklin',
#  "Tom O'Halleran"}

# %%
sherrod = relevant_legislators[(relevant_legislators['first_name'] == 'Sherrod') & (relevant_legislators['last_name'] == 'Brown')]['party'].values

# %%
sherrod
# Out:
# array(['Democrat'], dtype=object)

# %%
sherrod[0]
# Out:
# 'Democrat'

# %%
house.head()
# Out:
#   disclosure_date transaction_date ticker  \
# 0      2021-10-04       2021-09-27     BP
# 1      2021-10-04       2021-09-13    XOM
# 2      2021-10-04       2021-09-10   ILPT
# 3      2021-10-04       2021-09-28     PM
# 4      2021-10-04       2021-09-17    BLK
#
#                                    asset_description          type  amount  \
# 0                                             BP plc      purchase   15000
# 1                            Exxon Mobil Corporation      purchase   15000
# 2  Industrial Logistics Properties Trust - Common...      purchase   50000
# 3                   Phillip Morris International Inc      purchase   50000
# 4                                      BlackRock Inc  sale_partial   15000
#
#                 name represents chamber first_name  last_name       party  \
# 0      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 1      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 2      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 3      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 4  Alan S. Lowenthal       CA47   house       Alan  Lowenthal    Democrat
#
#                         birthday gender
# 0  1943-06-29T00:00:00.000000000      F
# 1  1943-06-29T00:00:00.000000000      F
# 2  1943-06-29T00:00:00.000000000      F
# 3  1943-06-29T00:00:00.000000000      F
# 4  1941-03-08T00:00:00.000000000      M

# %%
house.dtypes
# Out:
# disclosure_date      datetime64[ns]
# transaction_date     datetime64[ns]
# ticker                       object
# asset_description            object
# type                         object
# amount                        int64
# name                         object
# represents                   object
# chamber                      object
# first_name                   object
# last_name                    object
# party                        object
# birthday                     object
# gender                       object
# dtype: object

# %%
#house['party'] = str(house['party'])

# %% [markdown]
# When I do the following based on it being regular string [r'[\W_]+'...], it tells me I can't use a string on a byte type, but when I do it with b for byte (as found on [this site](https://stackoverflow.com/a/61720425)) it tells me it's a string and can't use byte. ????????

# %% [markdown]
# house['party'] = house['party'].map(lambda x: x[0])
# house['birthday'] = house['birthday'].map(lambda x: re.sub(br'[\W_]+', '', x))
# house['gender'] = house['gender'].map(lambda x: re.sub(br'[\W_]+', '', x))

# %%
house['party'] = house['party'].map(lambda x: x.replace(['[', '']).replace(']', ''))
house['birthday'] = house['birthday'].map(lambda x: re.sub(br'[\W_]+', '', x))
house['gender'] = house['gender'].map(lambda x: re.sub(br'[\W_]+', '', x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 house['party'] = house['party'].map(lambda x: x.replace(['[', '']).replace(']', ''))
#       2 house['birthday'] = house['birthday'].map(lambda x: re.sub(br'[\W_]+', '', x))
#       3 house['gender'] = house['gender'].map(lambda x: re.sub(br'[\W_]+', '', x))
#
# File ~/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/pandas/core/series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# -> 4237     new_values = self._map_values(arg, na_action=na_action)
#    4238     return self._constructor(new_values, index=self.index).__finalize__(
#    4239         self, method="map"
#    4240     )
#
# File ~/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/pandas/core/base.py:880, in IndexOpsMixin._map_values(self, mapper, na_action)
#     877         raise ValueError(msg)
#     879 # mapper is a function
# --> 880 new_values = map_f(values, mapper)
#     882 return new_values
#
# File ~/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [50], in <lambda>(x)
# ----> 1 house['party'] = house['party'].map(lambda x: x.replace(['[', '']).replace(']', ''))
#       2 house['birthday'] = house['birthday'].map(lambda x: re.sub(br'[\W_]+', '', x))
#       3 house['gender'] = house['gender'].map(lambda x: re.sub(br'[\W_]+', '', x))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'replace'

# %%
house.dtypes
# Out:
# disclosure_date      datetime64[ns]
# transaction_date     datetime64[ns]
# ticker                       object
# asset_description            object
# type                         object
# amount                        int64
# name                         object
# represents                   object
# chamber                      object
# first_name                   object
# last_name                    object
# party                        object
# birthday                     object
# gender                       object
# dtype: object

# %%
house['birthday'] = house['birthday'].map(datetime())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [207], in <cell line: 1>()
# ----> 1 house['birthday'] = house['birthday'].map(datetime())
#
# TypeError: function missing required argument 'year' (pos 1)

# %%
house.head()
# Out:
#   disclosure_date transaction_date ticker  \
# 0      2021-10-04       2021-09-27     BP
# 1      2021-10-04       2021-09-13    XOM
# 2      2021-10-04       2021-09-10   ILPT
# 3      2021-10-04       2021-09-28     PM
# 4      2021-10-04       2021-09-17    BLK
#
#                                    asset_description          type  amount  \
# 0                                             BP plc      purchase   15000
# 1                            Exxon Mobil Corporation      purchase   15000
# 2  Industrial Logistics Properties Trust - Common...      purchase   50000
# 3                   Phillip Morris International Inc      purchase   50000
# 4                                      BlackRock Inc  sale_partial   15000
#
#                 name represents chamber first_name  last_name       party  \
# 0      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 1      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 2      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 3      Virginia Foxx       NC05   house   Virginia       Foxx  Republican
# 4  Alan S. Lowenthal       CA47   house       Alan  Lowenthal    Democrat
#
#                         birthday gender
# 0  1943-06-29T00:00:00.000000000      F
# 1  1943-06-29T00:00:00.000000000      F
# 2  1943-06-29T00:00:00.000000000      F
# 3  1943-06-29T00:00:00.000000000      F
# 4  1941-03-08T00:00:00.000000000      M

# %%
house.dtypes
# Out:
# disclosure_date      datetime64[ns]
# transaction_date     datetime64[ns]
# ticker                       object
# asset_description            object
# type                         object
# amount                        int64
# name                         object
# represents                   object
# chamber                      object
# first_name                   object
# last_name                    object
# party                        object
# dtype: object

# %%
house.to_csv('./loren_data/clean_house_2022-07-15.csv')
